# %% [markdown]
# # Second question

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
data = pd.read_csv('titanic.csv')
data
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# # Third question

# %%
# Perform Below Visualizations.

plt.hist(data['age'])
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %%
#line plot

plt.plot(data['age'],data['sibsp'])

# %%
# box plot

plt.boxplot(data['survived'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1fd366ccf10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1fd366cd330>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1fd366ccc70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1fd366cd870>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1fd366cdb10>],
#  'means': []}

# %%
#bar chart

plt.bar(data['age'],data['survived'])
# Out:
# <BarContainer object of 891 artists>

# %%
# count plot

data.age.plot.hist(bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#violin plot

plt.violinplot(data['survived'])
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1fd380986d0>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1fd38098640>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1fd38098cd0>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1fd38099030>}

# %%
#scatter plot

plt.scatter(data['age'],data['pclass'])

# %%
# scatter plot using seaborn
sns.scatterplot(data.age)
# Out:
# <Axes: ylabel='age'>

# %%
#Joint plot using seaborn

sns.jointplot(data.pclass)

# %%
#boxplot using seaborn

sns.boxplot(data.age)
# Out:
# <Axes: >

# %%
#bar plot using seaborn

sns.barplot(data.age)
# Out:
# <Axes: >

# %%
#pair polt - Multivariate Analysis

sns.pairplot(data)
# Out:
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
# <__array_function__ internals>:180: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.

# %% [markdown]
# # Fourth question

# %%
# Perform descriptive statistics on the dataset
data.mean()
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\2999376053.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
data.mode()
# Out:
#    survived  pclass   sex   age  sibsp  parch  fare embarked  class  who  \
# 0         0       3  male  24.0      0      0  8.05        S  Third  man
#
#    adult_male deck  embark_town alive  alone
# 0        True    C  Southampton    no   True

# %%
data.median()
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\4184645713.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# survived       0.0000
# pclass         3.0000
# age           28.0000
# sibsp          0.0000
# parch          0.0000
# fare          14.4542
# adult_male     1.0000
# alone          1.0000
# dtype: float64

# %%
# skewness
data.skew()
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\2490412792.py:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew()
# survived      0.478523
# pclass       -0.630548
# age           0.389108
# sibsp         3.695352
# parch         2.749117
# fare          4.787317
# adult_male   -0.420431
# alone        -0.420431
# dtype: float64

# %%
# Distplot
print(sns.distplot(data['age'],color='red'))
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\3708498083.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   print(sns.distplot(data['age'],color='red'))
# Axes(0.125,0.11;0.775x0.77)

# %%
print(sns.distplot(data['survived'],color='blue'))
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\1548904511.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   print(sns.distplot(data['survived'],color='blue'))
# Axes(0.125,0.11;0.775x0.77)

# %%
# kurtosis
data.kurt()
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\2667652193.py:2: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.kurt()
# survived      -1.775005
# pclass        -1.280015
# age            0.178274
# sibsp         17.880420
# parch          9.778125
# fare          33.398141
# adult_male    -1.827345
# alone         -1.827345
# dtype: float64

# %%
# Range

data.max()
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\3800984161.py:3: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.max()
# survived             1
# pclass               3
# sex               male
# age               80.0
# sibsp                8
# parch                6
# fare          512.3292
# class            Third
# who              woman
# adult_male        True
# alive              yes
# alone             True
# dtype: object

# %%
data.min()
# Out:
# C:\Users\Chaithra\AppData\Local\Temp\ipykernel_14528\927168777.py:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.min()
# survived           0
# pclass             1
# sex           female
# age             0.42
# sibsp              0
# parch              0
# fare             0.0
# class          First
# who            child
# adult_male     False
# alive             no
# alone          False
# dtype: object

# %%
#range = data.max()-data.min()

# %%
# quantile=data.quantile(q=[0.75,0.25])
# quantile

# %% [markdown]
# # Fifth question

# %%
# Handle the Missing values.

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# Dropping the entire column
df.dropna(axis=1)
# Out:
#      survived  pclass     sex  sibsp  parch     fare   class    who  \
# 0           0       3    male      1      0   7.2500   Third    man
# 1           1       1  female      1      0  71.2833   First  woman
# 2           1       3  female      0      0   7.9250   Third  woman
# 3           1       1  female      1      0  53.1000   First  woman
# 4           0       3    male      0      0   8.0500   Third    man
# ..        ...     ...     ...    ...    ...      ...     ...    ...
# 886         0       2    male      0      0  13.0000  Second    man
# 887         1       1  female      0      0  30.0000   First  woman
# 888         0       3  female      1      2  23.4500   Third  woman
# 889         1       1    male      0      0  30.0000   First    man
# 890         0       3    male      0      0   7.7500   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# 2         False   yes   True
# 3         False   yes  False
# ...

# %% [markdown]
# # Tenth question

# %%
# Split the data into training and testing

# %%
x=df.iloc[:,0:1]

# %%
y=df.iloc[:,1:11]

# %%
x.head()
# Out:
#    survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0

# %%
y.head()
# Out:
#    pclass     sex   age  sibsp  parch     fare embarked  class    who  \
# 0       3    male  22.0      1      0   7.2500        S  Third    man
# 1       1  female  38.0      1      0  71.2833        C  First  woman
# 2       3  female  26.0      0      0   7.9250        S  Third  woman
# 3       1  female  35.0      1      0  53.1000        S  First  woman
# 4       3    male  35.0      0      0   8.0500        S  Third    man
#
#    adult_male
# 0        True
# 1       False
# 2       False
# 3       False
# 4        True

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (712, 1)
# (179, 1)
# (712, 10)
# (179, 10)

# %%
#Model Building
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %% [markdown]
# # Sixth question

# %%
# Find the outliers and replace the outliers
sns.boxplot(data.age)
# Out:
# <Axes: >

# %%
print(np.where(df['age']>65))
# Out:
# (array([ 33,  96, 116, 493, 630, 672, 745, 851], dtype=int64),)

# %%
# df.drop(0,inplace=True)
#df.dropna(axis=1, inplace=True)

# %% [markdown]
# # Seventh question

# %%
#Check for Categorical columns and perform encoding
#Encoding=Converting Categoricalto numerical

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
data["sex"]=le.fit_transform(data['sex'])

# %%
data.head()
# Out:
#    survived  pclass  sex   age  sibsp  parch     fare embarked  class    who  \
# 0         0       3    1  22.0      1      0   7.2500        S  Third    man
# 1         1       1    0  38.0      1      0  71.2833        C  First  woman
# 2         1       3    0  26.0      0      0   7.9250        S  Third  woman
# 3         1       1    0  35.0      1      0  53.1000        S  First  woman
# 4         0       3    1  35.0      0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
data.tail()
# Out:
#      survived  pclass  sex   age  sibsp  parch   fare embarked   class    who  \
# 886         0       2    1  27.0      0      0  13.00        S  Second    man
# 887         1       1    0  19.0      0      0  30.00        S   First  woman
# 888         0       3    0   NaN      1      2  23.45        S   Third  woman
# 889         1       1    1  26.0      0      0  30.00        C   First    man
# 890         0       3    1  32.0      0      0   7.75        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# 886        True  NaN  Southampton    no   True
# 887       False    B  Southampton   yes   True
# 888       False  NaN  Southampton    no  False
# 889        True    C    Cherbourg   yes   True
# 890        True  NaN   Queenstown    no   True

# %% [markdown]
# # Eigth question

# %%
# Split the data into dependent and independent variables

# %%
# Independent variables

X = df.iloc[:, :6].values
print(X)
# Out:
# [[ 0.  3.  1. 22.  1.  0.]
#  [ 1.  1.  0. 38.  1.  0.]
#  [ 1.  3.  0. 26.  0.  0.]
#  ...
#  [ 0.  3.  0. nan  1.  2.]
#  [ 1.  1.  1. 26.  0.  0.]
#  [ 0.  3.  1. 32.  0.  0.]]

# %%
Y = df.iloc[:, -1].values
print(Y)
# Out:
# [False False  True False  True  True  True False False False False  True
#   True False  True  True False  True False  True  True  True  True  True
#  False False  True False  True  True  True False  True  True False False
#   True  True False False False False  True False  True  True False  True
#  False False False  True False False False  True  True  True False False
#   True  True False False  True False  True  True False False  True False
#   True False  True  True  True  True False  True  True  True  True  True
#   True False False  True False  True  True  True False False  True  True
#   True False False False  True  True False  True False  True  True  True
#   True False  True False  True False  True  True  True False False False
#  False  True False  True False False  True  True False  True  True  True
#  False False  True  True False False  True  True False  True False  True
#   True False  True False False  True  True False  True False  True False
# ...

# %%
# Dependent variables
z = df.iloc[:, 6:].values
print(z)
# Out:
# [[7.25 'S' 'Third' ... 'Southampton' 'no' False]
#  [71.2833 'C' 'First' ... 'Cherbourg' 'yes' False]
#  [7.925 'S' 'Third' ... 'Southampton' 'yes' True]
#  ...
#  [23.45 'S' 'Third' ... 'Southampton' 'no' False]
#  [30.0 'C' 'First' ... 'Cherbourg' 'yes' True]
#  [7.75 'Q' 'Third' ... 'Queenstown' 'no' True]]

# %% [markdown]
# # Ninth question

# %%
# Scale the independent variables

# %%
# Standardization
from sklearn.preprocessing import StandardScaler

# %%
scale=StandardScaler()

# %%
x=data[['age','pclass']]

# %%
x
# Out:
#       age  pclass
# 0    22.0       3
# 1    38.0       1
# 2    26.0       3
# 3    35.0       1
# 4    35.0       3
# ..    ...     ...
# 886  27.0       2
# 887  19.0       1
# 888   NaN       3
# 889  26.0       1
# 890  32.0       3
#
# [891 rows x 2 columns]

# %%
st_scale=scale.fit_transform(x)

# %%
st_scale
# Out:
# array([[-0.53037664,  0.82737724],
#        [ 0.57183099, -1.56610693],
#        [-0.25482473,  0.82737724],
#        ...,
#        [        nan,  0.82737724],
#        [-0.25482473, -1.56610693],
#        [ 0.15850313,  0.82737724]])

# %%
# Normalisation
from sklearn.preprocessing import MinMaxScaler

# %%
min_max=MinMaxScaler()

# %%
norm=min_max.fit_transform(x)

# %%
norm
# Out:
# array([[0.27117366, 1.        ],
#        [0.4722292 , 0.        ],
#        [0.32143755, 1.        ],
#        ...,
#        [       nan, 1.        ],
#        [0.32143755, 0.        ],
#        [0.39683338, 1.        ]])
